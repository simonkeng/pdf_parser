# %%
import spacy
import nlp # my module 
import pandas as pd

# %%
data = nlp.read('pdf-data.pkl')
doc = nlp.apply_model(data)

# %%
unique_tokens = list()
for token in doc:
    
    if token.text not in unique_tokens:
        unique_tokens.append(token.text)

# %%
len(unique_tokens) # all the tokens that only appeared once
# Out:
# 4050

# %%
unique_tokens[0:20]
# Out:
# ['Article',
#  '\n',
#  'pubs.acs.org/jmc',
#  '\n\n',
#  'Mitigation',
#  'of',
#  'Acetylcholine',
#  'Esterase',
#  'Activity',
#  'in',
#  'the',
#  '1,7Diazacarbazole',
#  'Series',
#  'Inhibitors',
#  'Checkpoint',
#  'Kinase',
#  '1',
#  'Downloaded',
#  'via',
#  'SCHRODINGER']

# %%
for token in doc

# %%
ic50_dict = dict()

# %%
for token in doc:
    
    if token.shape_ == 'XXdd':
        ic50_dict[token.text] = token.sent

# %%
ic50_dict
# Out:
# {'CM19': Argenta, A Charles River Company, 8-9 Spire Green Centre, Harlow, Essex CM19 5TR, United Kingdom
#  ⊥
#
#  S, 'IC50': All other reported IC50 values are the
#  geometric mean derived from a minimum of two independent assays
#  with a maximum of 2.5-fold variation observed between the two assays., 'EC50': We targeted a cellular potency superior to that of compound 1 (EC50 98 nM)., 'EC10': GI50 values were plotted in an
#  isobologram plot to determine the eﬀective concentration of ChK1
#  inhibitor that potentiates the potency of gemcitabine 10-fold (EC10 fs)., 'GI50': GI50 values were plotted in an
#  isobologram plot to determine the eﬀective concentration of ChK1
#  inhibitor that potentiates the potency of gemcitabine 10-fold (EC10 fs)., 'HT29': In vivo activity in NCR nude mice bearing HT29 p53mut xenografts of compounds 19 and 30 dosed orally in MCT suspension 24 h following
#  gemcitabine.}

# %%
for token in doc:
    
    if token.shape_ == 'XXdd':
        print(token.text)
# Out:
# CM19
# IC50
# IC50
# IC50
# EC50
# IC50
# IC50
# EC10
# GI50
# IC50
# HT29
# IC50
# IC50
# IC50
# IC50
# GI50
# EC10

# %%
for token in doc:
    
    if token.shape_ == 'XXdd':
        print(token.sent)
# Out:
# Argenta, A Charles River Company, 8-9 Spire Green Centre, Harlow, Essex CM19 5TR, United Kingdom
# ⊥
#
# S
# Dimethylpiperidine compound 23 demonstrated the most potent AChE
# activity observed (AChE IC50 11 nM).
# In contrast, the spirocyclic
# oxetane 30, which diﬀered by the addition of a single oxygen atom,
# demonstrated a 220-fold reduction in activity (AChE IC50 2.42 μM)
# while maintaining good potency in the pHH3 cellular assay.
#
# Inhibition of ChK1 kinase activity in vitro (ChK1 IC50) was
# determined using an AlphaScreen peptide phosphorylation
# assay.11
# We targeted a cellular potency superior to that of compound 1 (EC50 98 nM).
# In vitro inhibition of human AChE was
# also monitored,15 with the goal of signiﬁcantly improving the
# margin observed for lead compound 1, which was found to be
# highly potent in this assay (IC50 18 nM).
#
# determination of the concentration of sensitizer (ChK1 inhibitor)
# required to reduce by 10-fold the IC50 of gemcitabine-induced
# ...

# %%
l = list()
for ent in doc.ents:
    
    if ent.label_ == 'GPE':
        l.append(ent.text)

# %%
l
# Out:
# ['\n',
#  'Karen',
#  '\n',
#  'Judi',
#  '\n',
#  '\n',
#  'South San Francisco',
#  'California',
#  '\n',
#  '\n',
#  'Harlow',
#  'United Kingdom',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'therapies.2',
#  '\n',
#  '\n',
#  'G1',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
# ...

# %%
for token in doc:
    if token.text == 'PDB':
        print(token.sent)
# Out:
# (b) High resolution (1.9 Å) cocrystal structure of 1 with the kinase domain of ChK1 (PDB code: 4QYH).
#
# High resolution cocrystal structures of (a) compound 7 (1.85 Å) and (b) compound 8 (1.85 Å) with ChK1 kinase domain indicating polar and
# hydrophobic contacts (PDB codes: 4RVL and 4RVK).
#
#
# An in silico docking model of AChE was prepared utilizing an
# available high resolution murine protein X-ray crystal structure
# (PDB code 2HA3, 2.25 Å).19
# Accession Codes
#
# Coordinates and structure factors for the ChK1 complexes with
# compounds 1, 7, 8, and 19 are deposited with the Protein Data
# Bank (PDB) with accession codes 4QYH, 4RVL, 4RVK, and
# 4RVM, respectively.
